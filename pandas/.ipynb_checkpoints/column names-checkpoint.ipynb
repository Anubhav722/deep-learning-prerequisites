# %%
import pandas as pd

# %%
x = pd.read_csv('/home/launchyard/Desktop/lazy_programmer/machine_learning_examples/airline/international-airline-passengers.csv', engine='python', skipfooter=3)

# %%
x.columns
# Out:
# Index(['Month', 'International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60'], dtype='object')

# %%
x.columns = ['month', 'passengers']

# %%
x.columns
# Out:
# Index(['month', 'passengers'], dtype='object')

# %% [markdown]
# ### Adding a new column

# %%
x['ones'] =1

# %%
x
# Out:
#        month  passengers  ones
# 0    1949-01         112     1
# 1    1949-02         118     1
# 2    1949-03         132     1
# 3    1949-04         129     1
# 4    1949-05         121     1
# 5    1949-06         135     1
# 6    1949-07         148     1
# 7    1949-08         148     1
# 8    1949-09         136     1
# 9    1949-10         119     1
# 10   1949-11         104     1
# 11   1949-12         118     1
# 12   1950-01         115     1
# 13   1950-02         126     1
# 14   1950-03         141     1
# 15   1950-04         135     1
# 16   1950-05         125     1
# 17   1950-06         149     1
# 18   1950-07         170     1
# 19   1950-08         170     1
# 20   1950-09         158     1
# 21   1950-10         133     1
# 22   1950-11         114     1
# 23   1950-12         140     1
# 24   1951-01         145     1
# 25   1951-02         150     1
# 26   1951-03         178     1
# 27   1951-04         163     1
# 28   1951-05         172     1
# ...

# %% [markdown]
# ### Using apply function

# %%
from datetime import datetime

# %%
x.head()
# Out:
#      month  passengers  ones
# 0  1949-01         112     1
# 1  1949-02         118     1
# 2  1949-03         132     1
# 3  1949-04         129     1
# 4  1949-05         121     1

# %%
datetime.strptime('1949-05', '%Y-%m')
# Out:
# datetime.datetime(1949, 5, 1, 0, 0)

# %%
x['dt'] = x.apply(lambda row: datetime.strptime(row['month'], "%Y-%m"), axis=1)

# %%
x.head()
# Out:
#      month  passengers  ones         dt
# 0  1949-01         112     1 1949-01-01
# 1  1949-02         118     1 1949-02-01
# 2  1949-03         132     1 1949-03-01
# 3  1949-04         129     1 1949-04-01
# 4  1949-05         121     1 1949-05-01
