# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,10,10)
# Starting point, Ending point, no. of points in between

# %%
y = np.sin(x)

# %%
y
# Out:
# array([ 0.        ,  0.8961922 ,  0.79522006, -0.19056796, -0.96431712,
#        -0.66510151,  0.37415123,  0.99709789,  0.51060568, -0.54402111])

# %%
plt.plot(x,y)

# %%
plt.show()

# %%
# Adding labels to axis
plt.plot(x,y)

# %%
plt.xlabel("Time")
# Out:
# Text(0.5,0,'Time')

# %%
plt.ylabel("Some function of time")
# Out:
# Text(0,0.5,'Some function of time')

# %%
plt.title("My Chart")
# Out:
# Text(0.5,1,'My Chart')

# %%
plt.show()

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
plt.plot(x,y)
plt.show()
